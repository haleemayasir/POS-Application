# %%
print("Haleema")
# Out:
# Haleema

# %%
from db import db_connect

db = db_connect()
cursor = db.cursor()

# %%
from inventory import get_products
products=get_products()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from inventory import get_products
#       2 products=get_products()
#
# ImportError: cannot import name 'get_products' from 'inventory' (f:\GitHub Projects\POS-Application\inventory.py)
